# %%
import mi_modulo as mm #Para importar un modulo/librería/fichero/biblioteca con un alias "mm"

print(mm.suma_2(2,5))
mm.x
# Out:
# 7
# 2

# %%
#Si solo quiero utilizar una función de mi modulo

from mi_modulo import suma_2

suma_2(1, -67)
# Out:
# -66

# %%
from mi_modulo import suma_2, resta_2

print(suma_2(1, -67))
resta_2(1, -67)
# Out:
# -66
# 68

# %%
from mi_modulo import suma_2, resta_2, x

print(suma_2(1, -67))
print(resta_2(1, -67))
print(x)
# Out:
# -66
# 68
# 2

# %%
#Esto son librerias
import pandas as pd
import numpy as np 
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-09d533fce718> in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import f.archivo_dentro_f as adf 
adf.f1()
# Out:
# 2

# %%
from f.k.fichero_j import * #el * sirve para importar todo dentro e ese fichero, pero no es una buena práctica. No lo vamos a utilizar, sólo es para que sepamos lo que es.
#Si modificas un fichero en jupyter notebook, hay que reiniciar el kernel y volver a importarlo para actualizarlo. 
import f.k.fichero_j as fichero_j
import f.k.fichero_j as fichero_j #Si se que función quiero importar
