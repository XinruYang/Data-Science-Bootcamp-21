# %% [markdown]
# # Scores *

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
from sklearn.datasets import load_iris, load_boston
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import requests

# %%
# print the graphs in the notebook
# %matplotlib inline

# set seaborn style to white
sns.set_style("white")

# %% [markdown]
# ### Step 2. Create the DataFrame it should look like below.
#
# This time you will create the data.

# %%
data = {'first_name': ['Tom', 'Molly', 'Tina', 'Jake', 'Amy'] ,'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 'Age': [42, 52, 36, 24, 76], 'female': [0, 1, 1, 0, 1], 'PreTestScore': [4, 24, 31, 2, 3], 'PostTestScore': [25, 94, 57, 62, 70]}

# %%
data = pd.DataFrame(data)
data
# Out:
#   first_name last_name  Age  female  PreTestScore  PostTestScore
# 0        Tom    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   76       1             3             70

# %%
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
x=np.array(data["Age"])

data['PreTestScore']
# Out:
# 0     4
# 1    24
# 2    31
# 3     2
# 4     3
# Name: PreTestScore, dtype: int64

# %%
plt.scatter(x=data['PreTestScore'], y=data["PostTestScore"], s=data["Age"])
plt.xlabel('PreTestScore')
plt.ylabel('PostTestScore')
# Out:
# Text(0, 0.5, 'PostTestScore')

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
plt.scatter(x=data['PreTestScore'], y=data["PostTestScore"], s=4.5*data["PostTestScore"], c=data["female"],edgecolors="k")
