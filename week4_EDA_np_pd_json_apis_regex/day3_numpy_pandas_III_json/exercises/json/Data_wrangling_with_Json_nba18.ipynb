# %% [markdown]
# ## Working on s

# %%
import requests
import 
import pandas as pd

# %%
r = requests.get(url='http://data.nba.net/prod/v2/2018/teams.')
_readed = .loads(r.text)
_readed
# Out:
# onfName': 'West',
#     'divName': 'Pacific'},
#    {'isNBAFranchise': False,
#     'isAllStar': False,
#     'city': 'Guangzhou',
#     'altCityName': 'Guangzhou',
#     'fullName': 'Guangzhou Long-Lions',
#     'tricode': 'GUA',
#     'teamId': '15018',
#     'nickname': 'Long-Lions',
#     'urlName': 'long-lions',
#     'confName': 'Intl',
#     'divName': ''},
#    {'isNBAFranchise': False,
#     'isAllStar': False,
#     'city': 'Haifa',
#     'altCityName': 'Haifa',
#     'fullName': 'Maccabi Haifa',
#     'tricode': 'MAC',
#     'teamId': '93',
#     'nickname': 'Maccabi Haifa',
#     'urlName': 'maccabi_haifa',
#     'confName': 'Intl',
#     'divName': ''},
#    {'isNBAFranchise': True,
#     'isAllStar': False,
#     'city': 'Houston',
#     'altCityName': 'Houston',
#     'fullName': 'Houston Rockets',
#     'tricode': 'HOU',
#     'teamId': '1610612745',
#     'nickname': 'Rockets',
#     'urlName': 'rockets',
#     'confName': 'West',
#     'divName': 'Southwest'},
# ...

# %%
df = pd.DataFrame(_readed)
df
# Out:
#                                           _internal  \
# pubDateTime                 2018-08-30 20:00:04.422
# xslt         xsl/league/roster/marty_teams_list.xsl
# eventName                             league_roster
# standard                                        NaN
# africa                                          NaN
# sacramento                                      NaN
# vegas                                           NaN
# utah                                            NaN
#
#                                                         league
# pubDateTime                                                NaN
# xslt                                                       NaN
# eventName                                                  NaN
# standard     [{'isNBAFranchise': False, 'isAllStar': True, ...
# africa       [{'isNBAFranchise': False, 'isAllStar': False,...
# sacramento   [{'isNBAFranchise': True, 'isAllStar': False, ...
# ...

# %%
df2 = df.loc["standard":, "league":]
df2
# Out:
#                                                        league
# standard    [{'isNBAFranchise': False, 'isAllStar': True, ...
# africa      [{'isNBAFranchise': False, 'isAllStar': False,...
# sacramento  [{'isNBAFranchise': True, 'isAllStar': False, ...
# vegas       [{'isNBAFranchise': True, 'isAllStar': False, ...
# utah        [{'isNBAFranchise': True, 'isAllStar': False, ...

# %%
# Pasar una serie a DataFrame
df_serie = df.loc["standard":, "league"]
df3 = pd.DataFrame(df_serie)
df3
# Out:
#                                                        league
# standard    [{'isNBAFranchise': False, 'isAllStar': True, ...
# africa      [{'isNBAFranchise': False, 'isAllStar': False,...
# sacramento  [{'isNBAFranchise': True, 'isAllStar': False, ...
# vegas       [{'isNBAFranchise': True, 'isAllStar': False, ...
# utah        [{'isNBAFranchise': True, 'isAllStar': False, ...

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are s inside the original . For that, we have to mining the  (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %% [markdown]
# #### GOAL

# %% [markdown]
# ![](_df_goal_nba.png)
